# %%
import qutip as qt
import gates as gate
import numpy as np
from solovay_kitaev import solovay_kitaev
from utils import load_tree

U = gate.R([0.21, 0.14, 0.7], 7 * np.pi / 6)

tree = load_tree('trees/HT_15.pkl')

U_approx = solovay_kitaev(U, tree, 2)

print(U.full())
print(U_approx.full())
print(qt.tracedist(U, U_approx))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 import qutip as qt
# ----> 2 import gates as gate
#       3 import numpy as np
#       4 from solovay_kitaev import solovay_kitaev
#
# File ~/Desktop/Bachelor/VSCode/Bachelor/SolovayKitaev/gates.py:10
#       8 Y = qt.sigmay()
#       9 Z = qt.sigmaz()
# ---> 10 H = qt.hadamard_transform()
#      11 S = qt.phasegate(np.pi / 2)
#      12 T = qt.phasegate(np.pi / 4)
#
# AttributeError: module 'qutip' has no attribute 'hadamard_transform'

# %%
pip list
# Out:
# Package                   Version
# ------------------------- ----------------
# annotated-types           0.7.0
# anyio                     4.4.0
# appdirs                   1.4.4
# apturl                    0.5.2
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# astunparse                1.6.3
# async-lru                 2.0.4
# attrs                     24.2.0
# autograd                  1.7.0
# autoray                   0.7.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bitarray                  2.9.2
# bitstring                 4.2.3
# bleach                    6.1.0
# blinker                   1.4
# Brlapi                    0.8.3
# cachetools                5.5.2
# certifi                   2020.6.20
# cffi                      1.17.0
# chardet                   4.0.0
# charset-normalizer        3.3.2
# click                     8.0.3
# colorama                  0.4.4
# comm                      0.2.2
# command-not-found         0.3
# contourpy                 1.2.1
# cryptography              3.4.8
# cupshelpers               1.0
# cycler                    0.12.1
# data                      0.4
# dbus-python               1.2.18
# debugpy                   1.8.5
# decorator                 5.1.1
# defer                     1.0.6
# defusedxml                0.7.1
# diastatic-malt            2.15.2
# dill                      0.3.8
# distro                    1.7.0
# distro-info               1.1+ubuntu0.2
# entrypoints               0.4
# exceptiongroup            1.2.2
# executing                 2.0.1
# fastjsonschema            2.20.0
# fonttools                 4.53.1
# fqdn                      1.5.1
# funcsigs                  1.0.2
# future                    1.0.0
# gast                      0.6.0
# h11                       0.14.0
# httpcore                  1.0.5
# httplib2                  0.20.2
# httpx                     0.27.0
# ibm-cloud-sdk-core        3.20.6
# ibm-platform-services     0.56.0
# idna                      3.3
# importlib-metadata        4.6.4
# ipykernel                 6.29.5
# ipython                   8.26.0
# ipywidgets                8.1.3
# isoduration               20.11.0
# jedi                      0.19.1
# jeepney                   0.7.1
# Jinja2                    3.1.4
# joblib                    1.4.2
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter                   1.0.0
# jupyter_client            8.6.2
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.11
# keyring                   23.5.0
# kiwisolver                1.4.5
# language-selector         0.1
# latex                     0.7.0
# launchpadlib              1.10.16
# lazr.restfulclient        0.14.4
# lazr.uri                  1.0.6
# louis                     3.20.0
# macaroonbakery            1.3.1
# MarkupSafe                2.1.5
# matplotlib                3.9.2
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# more-itertools            8.10.0
# mpmath                    1.3.0
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# netifaces                 0.11.0
# networkx                  3.3
# notebook                  7.2.1
# notebook_shim             0.2.4
# ntlm-auth                 1.5.0
# numpy                     1.23.5
# oauthlib                  3.2.0
# olefile                   0.46
# overrides                 7.7.0
# packaging                 24.1
# pandas                    2.2.3
# pandocfilters             1.5.1
# parso                     0.8.4
# pbr                       6.0.0
# PennyLane                 0.40.0
# PennyLane_Lightning       0.40.0
# pexpect                   4.8.0
# Pillow                    9.0.1
# pip                       25.0.1
# pipdeptree                2.23.1
# platformdirs              4.2.2
# ply                       3.11
# prometheus_client         0.20.0
# prompt_toolkit            3.0.47
# protobuf                  3.12.4
# psutil                    6.0.0
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pybind11                  2.9.1
# pycairo                   1.20.1
# pycparser                 2.22
# pycups                    2.0.1
# pydantic                  2.8.2
# pydantic_core             2.20.1
# Pygments                  2.18.0
# PyGObject                 3.42.1
# PyJWT                     2.9.0
# pylatexenc                2.10
# pymacaroons               0.13.0
# PyMatching                2.2.1
# PyNaCl                    1.5.0
# pyparsing                 2.4.7
# pyRFC3339                 1.1
# pyspnego                  0.11.1
# python-apt                2.4.0+ubuntu4
# python-dateutil           2.9.0.post0
# python-debian             0.1.43+ubuntu1.1
# python-json-logger        2.0.7
# pytz                      2022.1
# pyxdg                     0.27
# PyYAML                    5.4.1
# pyzmq                     26.1.1
# qiskit                    1.2.0
# qiskit-aer                0.14.2
# qiskit-ibm-provider       0.11.0
# qiskit-ibm-runtime        0.28.0
# qiskit-ibmq-provider      0.20.2
# qiskit_qec                0.0.1
# qtcodes                   0.2.0
# qtconsole                 5.5.2
# QtPy                      2.4.1
# qutip                     5.1.1
# referencing               0.35.1
# reportlab                 3.6.8
# requests                  2.32.3
# requests-ntlm             1.1.0
# requests-unixsocket       0.2.0
# retworkx                  0.15.1
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.20.0
# rustworkx                 0.15.1
# scikit-learn              1.6.1
# scipy                     1.14.0
# scipy-openblas32          0.3.29.0.0
# SecretStorage             3.3.1
# Send2Trash                1.8.3
# setuptools                59.6.0
# shutilwhich               1.1.0
# simplejson                3.17.6
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.6
# ssh-import-id             5.11
# stac                      1.1.0
# stack-data                0.6.3
# stevedore                 5.2.0
# stim                      1.13.0
# symengine                 0.11.0
# sympy                     1.13.2
# systemd-python            234
# tempdir                   0.7.1
# termcolor                 2.5.0
# terminado                 0.18.1
# testtools                 2.7.2
# threadpoolctl             3.5.0
# tinycss2                  1.3.0
# tomli                     2.0.1
# tomlkit                   0.13.2
# tornado                   6.4.1
# tqdm                      4.66.5
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240316
# typing_extensions         4.12.2
# tzdata                    2024.2
# ubuntu-drivers-common     0.0.0
# ubuntu-pro-client         8001
# ufw                       0.36.1
# unattended-upgrades       0.1
# uri-template              1.3.0
# urllib3                   2.2.2
# wadllib                   1.3.6
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# websockets                12.0
# wheel                     0.37.1
# widgetsnbextension        4.0.11
# xdg                       5
# xkit                      0.0.0
# zipp                      1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pennylane as qml

op  = qml.RZ(np.pi/8, wires=0)

# Get the gate decomposition in ['T', 'T*', 'H']
ops = qml.ops.sk_decomposition(op, epsilon=1e-1, basis_set=("T","T*","H","S","S*"))

# Get the approximate matrix from the ops
matrix_sk = qml.prod(*reversed(ops)).matrix()

print(ops)
# Out:
# [S(0), H(0), T(0), H(0), T(0), H(0), T(0), H(0), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), S(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(S(0)), T(0), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), Adjoint(S(0)), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(S(0)), T(0), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), S(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), S(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), Adjoint(T(0)), S(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(S(0)), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), T(0), H(0), T(0), H(0), Adjoint(S(0)), T(0), H(0), T(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), T(0), H(0), Adjoint(T(0)), S(0), H(0), T(0), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), H(0), Adjoint(T(0)), GlobalPhase(array(0.78539816), wires=[])]
